# %%
import numpy as np
import matplotlib.pyplot as pl

# %%
phi1=[7.72525542189905767287E-01,7.72848542168027563548E-01,7.69021972227589056814E-01,7.68700885604844064147E-01,7.72624074349405276507E-01,7.72947123370641531181E-01,7.69120923664238453910E-01,7.68799787326781114416E-01]
theta1=[1.63231296519506230425E+00,1.63235326682789327890E+00,1.63182332774519323060E+00,1.63178322143377840803E+00,1.63158953241266835299E+00,1.63162935859045443721E+00,1.63109806314937078042E+00,1.63105843496880154042E+00]
phi2=[7.72947123370641531181E-01,7.68799787326781114416E-01,7.68700885604844064147E-01,7.69021972227589056814E-01,7.72525542189905767287E-01,7.72848542168027563548E-01]
theta2=[1.63162935859045443721E+00,1.63105843496880154042E+00,1.63178322143377840803E+00,1.63182332774519323060E+00,1.63231296519506230425E+00,1.63235326682789327890E+00]

# %%
pl.scatter(phi1,theta1)
pl.scatter(phi2,theta2,marker='*')
pl.plot(phi2,theta2)

# %%
pl.plot(phi2,theta2)

# %%
import healpy as hp
hp.query_polygon(2048, xyz.T, inclusive=True)
